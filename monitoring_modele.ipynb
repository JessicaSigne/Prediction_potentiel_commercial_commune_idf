# %%
from datetime import datetime

periode_cible = datetime.now().strftime("%Y%m")
annee_cible = datetime.now().year

print(f"Période cible : {periode_cible}")
print(f"Année cible : {annee_cible}")
